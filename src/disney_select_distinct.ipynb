-- %% [markdown]
-- # Command: SELECT DISTINCT
-- ## Server: Microsoft SQL Server
-- ## Database: disney
-- ## Author: Prasert Kanawatanachai
-- ## YouTube: https://youtu.be/CpR9U9s0ktc

-- %% [markdown]
-- ```
-- SELECT [ ALL | DISTINCT ]
--     [TOP ( expression ) [PERCENT] [ WITH TIES ] ]
-- 	FROM table_source
-- 	[ WHERE search_condition ]
-- 	[ GROUP BY group_by_expression ]
-- 	[ HAVING search_condition ]
-- 	[ ORDER BY order_expression [ ASC | DESC ] ]
-- ```

-- %%
SELECT * from movie_gross
-- Out:
-- (579 rows affected)
-- Total execution time: 00:00:00.254
-- ...

-- %%
select distinct genre from movie_gross
-- Out:
-- (13 rows affected)
-- Total execution time: 00:00:00.024
-- <table><tr><th>genre</th></tr><tr><td>NULL</td></tr><tr><td>Action</td></tr><tr><td>Adventure</td></tr><tr><td>Black Comedy</td></tr><tr><td>Comedy</td></tr><tr><td>Concert/Performance</td></tr><tr><td>Documentary</td></tr><tr><td>Drama</td></tr><tr><td>Horror</td></tr><tr><td>Musical</td></tr><tr><td>Romantic Comedy</td></tr><tr><td>Thriller/Suspense</td></tr><tr><td>Western</td></tr></table>

-- %%
select distinct movie_title from movie_gross
-- Out:
-- (573 rows affected)
-- Total execution time: 00:00:00.986
-- ...

-- %%
SELECT movie_title, count(*) cnt from movie_gross 
    group by movie_title 
    having count(*) > 1
    order by cnt desc
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.016
-- <table><tr><th>movie_title</th><th>cnt</th></tr><tr><td>The Jungle Book</td><td>3</td></tr><tr><td>101 Dalmatians</td><td>2</td></tr><tr><td>Bad Company</td><td>2</td></tr><tr><td>Cinderella</td><td>2</td></tr><tr><td>Freaky Friday</td><td>2</td></tr></table>

-- %%
select distinct mpaa_rating from movie_gross
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.017
-- <table><tr><th>mpaa_rating</th></tr><tr><td>NULL</td></tr><tr><td>G</td></tr><tr><td>Not Rated</td></tr><tr><td>PG</td></tr><tr><td>PG-13</td></tr><tr><td>R</td></tr></table>

-- %%
select release_date, datepart(year, release_date) 
    from movie_gross
-- Out:
-- (579 rows affected)
-- Total execution time: 00:00:00.028
-- ...

-- %%
select distinct datepart(year, release_date) 
    from movie_gross
-- Out:
-- (54 rows affected)
-- Total execution time: 00:00:00.034
-- ...

-- %%
select * from voice_actor
-- Out:
-- (935 rows affected)
-- Total execution time: 00:00:00.060
-- ...

-- %%
select distinct voice_actor from voice_actor
-- Out:
-- (655 rows affected)
-- Total execution time: 00:00:00.070
-- ...

-- %%
select distinct * from movie_gross
-- Out:
-- (579 rows affected)
-- Total execution time: 00:00:01.982
-- ...
